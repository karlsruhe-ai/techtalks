# %%
using Gadfly, RDatasets
import ForwardDiff: gradient

# %% [markdown]
# ### Sanity check

# %%
f(x) = sum(x)*log(abs(sum(x)))
f([2,5])
# Out:
# 13.621371043387192

# %%
gradient(f, [2,5])
# Out:
# 2-element Array{Float64,1}:
#  2.94591
#  2.94591

# %% [markdown]
# ### Generic gradient descent

# %%
function GradientDescent(L, x0; rate=.1, N=100, eps=.001)
    for i = 1:N 
        ∇L = gradient(L, x0)
        if norm(∇L) < eps
            break
        end
        x0 -= rate * ∇L
    end
    x0
end
# Out:
# GradientDescent (generic function with 1 method)

# %% [markdown]
# ### Curve fitting

# %%
x = rand(20) * 6
w = [.5; -2.; 1]
y = [x.^2  x  ones(x)] * w  + rand(size(x)) * .2
#         ^^^                      ^^^
#   2nd degree polynomial       Noisy data

p = plot(
    layer(x=x, y=y, Geom.point),
    layer(x -> dot([x^2; x; 1], w), 0, 6, Theme(default_color=colorant"green")),
    Guide.title("Ground truth: w = $w"))
draw(PNG(6inch, 4inch), p)
# Out:
# Compose.Image{Compose.PNGBackend}(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=38723, maxsize=Inf, ptr=38724, mark=-1),Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Cairo.CairoContext(Ptr{Void} @0x0000000000000000,Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Ptr{Void} @0x00000000051670e0),576.0,384.0,RGBA{Float64}(0.0,0.0,0.0,0.0),RGBA{Float64}(0.0,0.0,0.0,1.0),Float64[],Compose.LineCapButt(),Compose.LineJoinMiter(),true,0.3mm,3.880555555555555mm,"Helvetica Neue,Helvetica,Arial,sans",Nullable{Compose.ClipPrimitive{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Compose.ImagePropertyState[],Compose.ImagePropertyFrame[],Dict{Type,Nullable{Compose.Property}}(),true,false,nothing,true,true,3.7795275590551185,Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(),Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}())

# %%
esw = GradientDescent([1,1,1], rate=.001, N=5000) do w
    mean(([x.^2  x  ones(x)] * w - y).^2)
end

p = plot(
    layer(x=x, y=y, Geom.point),
    layer(x -> dot([x^2; x; 1], w), 0, 6, Theme(default_color=colorant"green")),
    layer(x -> dot([x^2; x; 1], esw), 0, 6, Theme(default_color=colorant"red")),
    Guide.title("Estimate: w = $esw"))
draw(PNG(6inch, 4inch), p)
# Out:
# Compose.Image{Compose.PNGBackend}(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=42049, maxsize=Inf, ptr=42050, mark=-1),Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Cairo.CairoContext(Ptr{Void} @0x0000000000000000,Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Ptr{Void} @0x0000000005167190),576.0,384.0,RGBA{Float64}(0.0,0.0,0.0,0.0),RGBA{Float64}(0.0,0.0,0.0,1.0),Float64[],Compose.LineCapButt(),Compose.LineJoinMiter(),true,0.3mm,3.880555555555555mm,"Helvetica Neue,Helvetica,Arial,sans",Nullable{Compose.ClipPrimitive{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Compose.ImagePropertyState[],Compose.ImagePropertyFrame[],Dict{Type,Nullable{Compose.Property}}(),true,false,nothing,true,true,3.7795275590551185,Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(),Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}())

# %%
# With L1 regularization

esw = GradientDescent([1,1,1], rate=.001, N=5000) do w
    mean(([x.^2  x  ones(x)] * w - y).^2) + sum(abs(w))
end

p = plot(
    layer(x=x, y=y, Geom.point),
    layer(x -> dot([x^2; x; 1], w), 0, 6, Theme(default_color=colorant"green")),
    layer(x -> dot([x^2; x; 1], esw), 0, 6, Theme(default_color=colorant"red")),
    Guide.title("Estimate: w = $esw"))
draw(PNG(6inch, 4inch), p)
# Out:
# Compose.Image{Compose.PNGBackend}(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=42926, maxsize=Inf, ptr=42927, mark=-1),Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Cairo.CairoContext(Ptr{Void} @0x0000000000000000,Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Ptr{Void} @0x0000000005167240),576.0,384.0,RGBA{Float64}(0.0,0.0,0.0,0.0),RGBA{Float64}(0.0,0.0,0.0,1.0),Float64[],Compose.LineCapButt(),Compose.LineJoinMiter(),true,0.3mm,3.880555555555555mm,"Helvetica Neue,Helvetica,Arial,sans",Nullable{Compose.ClipPrimitive{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Compose.ImagePropertyState[],Compose.ImagePropertyFrame[],Dict{Type,Nullable{Compose.Property}}(),true,false,nothing,true,true,3.7795275590551185,Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(),Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}())

# %% [markdown]
# ### Iris dataset

# %%
iris = dataset("datasets", "iris")
p = plot(iris, x=:SepalWidth, y=:SepalLength, color=:Species)
draw(PNG(6inch, 4inch), p)
# Out:
# Compose.Image{Compose.PNGBackend}(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=51796, maxsize=Inf, ptr=51797, mark=-1),Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Cairo.CairoContext(Ptr{Void} @0x0000000000000000,Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Ptr{Void} @0x00000000051672f0),576.0,384.0,RGBA{Float64}(0.0,0.0,0.0,0.0),RGBA{Float64}(0.0,0.0,0.0,1.0),Float64[],Compose.LineCapButt(),Compose.LineJoinMiter(),true,0.3mm,3.880555555555555mm,"Helvetica Neue,Helvetica,Arial,sans",Nullable{Compose.ClipPrimitive{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Compose.ImagePropertyState[],Compose.ImagePropertyFrame[],Dict{Type,Nullable{Compose.Property}}(Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.SVGClassPrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.StrokePrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.JSCallPrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.FillPrimitive},#NULL)),true,false,nothing,true,true,3.7795275590551185,Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(),Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}())

# %%
# Classify setosa vs. rest
X = convert(Array, iris[[:SepalWidth, :SepalLength, :PetalWidth]])
y = convert(Array{Int64}, iris[:Species] .== "setosa");

# %% [markdown]
# ### Logistic Regression

# %%
logit(x,w) = 1 / (1 + exp(-dot([x; 1], w)))

logisticRegression(X,y) =
    GradientDescent(rand(size(X,2)+1)) do w
        # Loss is negative log likelihood
        e = 0
        for i = 1:size(X,1) # <<< A loop over run time data
            if y[i] == 0    # << Branch using run time data
                e += log(1-logit(X[i,:], w))
            else
                e += log(logit(X[i,:], w))
            end
        end
        -e/size(X,1)
    end
# Out:
# logisticRegression (generic function with 1 method)

# %%
w = logisticRegression(X,y)
pred = [logit(X[i,:], w) > .5 for i = 1:size(X,1)]
p = plot(x=X[:,1], y=X[:,2], color=pred, Guide.title("w = $w"))
draw(PNG(6inch, 4inch), p)
# Out:
# Compose.Image{Compose.PNGBackend}(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=50652, maxsize=Inf, ptr=50653, mark=-1),Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Cairo.CairoContext(Ptr{Void} @0x0000000000000000,Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Ptr{Void} @0x00000000051673a0),576.0,384.0,RGBA{Float64}(0.0,0.0,0.0,0.0),RGBA{Float64}(0.0,0.0,0.0,1.0),Float64[],Compose.LineCapButt(),Compose.LineJoinMiter(),true,0.3mm,3.880555555555555mm,"Helvetica Neue,Helvetica,Arial,sans",Nullable{Compose.ClipPrimitive{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Compose.ImagePropertyState[],Compose.ImagePropertyFrame[],Dict{Type,Nullable{Compose.Property}}(Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.SVGClassPrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.StrokePrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.JSCallPrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.FillPrimitive},#NULL)),true,false,nothing,true,true,3.7795275590551185,Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(),Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}())

# %% [markdown]
# ### Bagging Gradient Descent

# %%
baggingLogisticRegression(X,y) =
    GradientDescent(rand(size(X,2)+1)) do w
        e = 0
        for k = 1:size(X,1)*.6
        
            i = rand(1:size(X,1)) # <<< Random state!
    
            if y[i] == 0
                e += log(1-logit(X[i,:], w))
            else
                e += log(logit(X[i,:], w))
            end
        end
        -e/(size(X,1)*.6)
    end
# Out:
# baggingLogisticRegression (generic function with 1 method)

# %%
w = baggingLogisticRegression(X,y)
pred = [logit(X[i,:], w) > .5 for i = 1:size(X,1)]
p = plot(x=X[:,1], y=X[:,2], color=pred, Guide.title("w = $w"))
draw(PNG(6inch, 4inch), p)
# Out:
# Compose.Image{Compose.PNGBackend}(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=50399, maxsize=Inf, ptr=50400, mark=-1),Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Cairo.CairoContext(Ptr{Void} @0x0000000000000000,Cairo.CairoSurface{UInt32}(Ptr{Void} @0x0000000000000000,576.0,384.0,#undef),Ptr{Void} @0x0000000005167450),576.0,384.0,RGBA{Float64}(0.0,0.0,0.0,0.0),RGBA{Float64}(0.0,0.0,0.0,1.0),Float64[],Compose.LineCapButt(),Compose.LineJoinMiter(),true,0.3mm,3.880555555555555mm,"Helvetica Neue,Helvetica,Arial,sans",Nullable{Compose.ClipPrimitive{P<:Tuple{Vararg{Measures.Measure,N}}}}(),Compose.ImagePropertyState[],Compose.ImagePropertyFrame[],Dict{Type,Nullable{Compose.Property}}(Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.SVGClassPrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.StrokePrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.JSCallPrimitive},#NULL),Pair{Type,Nullable{Compose.Property}}(Compose.Property{Compose.FillPrimitive},#NULL)),true,false,nothing,true,true,3.7795275590551185,Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}(),Nullable{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}())
